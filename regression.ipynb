# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('D:\linear regression sklearn\Linear Regression - Sheet1.csv')

# %%
df.tail(200)
# Out:
#        X           Y
# 100  101   70.555556
# 101  102   71.222222
# 102  103   71.888889
# 103  104   72.555556
# 104  105   73.222222
# ..   ...         ...
# 295  296  200.555556
# 296  297  201.222222
# 297  298  201.888889
# 298  299    1.888889
# 299  300    1.888889
#
# [200 rows x 2 columns]

# %%
#assinging values to x and y
X = df['X']
Y = df['Y']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25)
X_train = X_train.to_numpy().reshape(-1, 1)
Y_train = Y_train

# %%
plt.figure(figsize=(30,30))
plt.scatter(X_train,Y_train)

# %%
plt.figure(figsize=(30,30))
plt.scatter(X_test , Y_test , color = 'r')

# %%
model = LinearRegression()

model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test.to_numpy().reshape(-1,1))
print(Y_pred)
# Out:
# [ 14.16729229 129.33664856  31.88565479 153.38299767 156.54699097
#   67.95517846  95.16552087  59.09599721 121.11026597 105.92309811
#   79.34555435  71.75197042 141.35982311  16.06568827  45.17442667
#   26.82326551  98.32951418 133.76623918 111.61828606 142.62542044
#   81.876749   143.89101776 183.75733339 123.64146061  63.52558783
#   54.03360792  42.01043337  42.64323203  35.68244676 186.28852803
#   78.71275569  83.14234632 181.22613875  28.72166149 179.32774276
#  169.20296419 187.55412535 160.9765816  152.75019901  97.06391686
#  149.58620571 107.82149409  22.39367488  60.36159453  58.46319855
#  126.17265525 146.4222124  131.23504454  78.07995703  82.50954766
#  158.44538696  50.23681596 157.8125883  186.92132669  19.86248024
#   41.3776347  129.96944722  89.47033293 136.93023249 119.84466865
#   53.40080926  57.83039989  48.97121863 166.67176955 117.94627266
#   19.22968158 121.74306463 105.29029945 128.7038499   11.00329898
# ...

# %%
plt.figure(figsize=(30,30))
plt.scatter(X_test,Y_test)
plt.plot(X_test, Y_pred , color = 'r')

# %%
train_accuracy = model.score(X_train,Y_train)
train_accuracy
# Out:
# 0.8999740633126733

# %%
test_accuracy = model.score(X_test.to_numpy().reshape(-1,1),Y_test)
test_accuracy
# Out:
# 0.996520604683681

# %%
test_point = np.array([3.9 , 4.9 , 3.9 ]).reshape(-1,1)
test_point_pred = model.predict(test_point)
print(test_point_pred)
test_point_accuracy = model.score(test_point,test_point_pred)
print(test_point_accuracy)
# Out:
# [9.04162314 9.6744218  9.04162314]
# 1.0

# %%
print(model.intercept_)
print(model.coef_)
# Out:
# 6.5737083589346526
# [0.63279866]
